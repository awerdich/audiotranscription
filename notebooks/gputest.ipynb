# %% [markdown]
# ### Test GPU availability in the container ###

# %%
import sys
import os
import numpy as np
import pandas as pd

# PyTorch
import torch

# Hugging Face Library

# %load_ext autoreload
# %autoreload 2
import audiotranscription

print(f'Authors: {audiotranscription.__authors__}')
print(f'Project version: {audiotranscription.__version__}')
print(f'Python version:  {sys.version}')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 15
#      12 get_ipython().run_line_magic('autoreload', '2')
#      13 import audiotranscription
# ---> 15 print(f'Authors: {audiotranscription.__authors__}')
#      16 print(f'Project version: {audiotranscription.__version__}')
#      17 print(f'Python version:  {sys.version}')
#
# AttributeError: module 'audiotranscription' has no attribute '__authors__'

# %%
# GPU checks
def get_gpu_info(device_number: int = None):

    if device_number is None:
        is_cuda = torch.cuda.is_available()
        print(f'CUDA available: {is_cuda}')
        print(f'Number of GPUs found:  {torch.cuda.device_count()}')
        if is_cuda:
            print(f'Current device ID: {torch.cuda.current_device()}')
            print(f'GPU device name:   {torch.cuda.get_device_name(0)}')
            print(f'PyTorch version:   {torch.__version__}')
            print(f'CUDA version:      {torch.version.cuda}')
            print(f'CUDNN version:     {torch.backends.cudnn.version()}')
            device_str = 'cuda:0'
            torch.cuda.empty_cache()
        else:
            device_str = 'cpu'
    else:
        device_str = f'cuda:{device_number}'

    info_msg = f'Current device:    {device_str}'
    print(info_msg)
    device = torch.device(device_str)
    logger.info(info_msg)

    return device, device_str

device, device_str = get_device_name()
